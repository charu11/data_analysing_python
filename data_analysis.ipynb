# %% [markdown]
# <a href="https://colab.research.google.com/github/charu11/data_analysing_python/blob/master/data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/drive/My Drive/data_analysis_python/avocado-prices/avocado.csv')
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  ...          type  year  region
# 0           0  2015-12-27          1.33  ...  conventional  2015  Albany
# 1           1  2015-12-20          1.35  ...  conventional  2015  Albany
# 2           2  2015-12-13          0.93  ...  conventional  2015  Albany
# 3           3  2015-12-06          1.08  ...  conventional  2015  Albany
# 4           4  2015-11-29          1.28  ...  conventional  2015  Albany
#
# [5 rows x 14 columns]

# %%
df.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  ...     type  year            region
# 18244           7  2018-02-04          1.63  ...  organic  2018  WestTexNewMexico
# 18245           8  2018-01-28          1.71  ...  organic  2018  WestTexNewMexico
# 18246           9  2018-01-21          1.87  ...  organic  2018  WestTexNewMexico
# 18247          10  2018-01-14          1.93  ...  organic  2018  WestTexNewMexico
# 18248          11  2018-01-07          1.62  ...  organic  2018  WestTexNewMexico
#
# [5 rows x 14 columns]

# %%
df.AveragePrice.head()
# Out:
# 0    1.33
# 1    1.35
# 2    0.93
# 3    1.08
# 4    1.28
# Name: AveragePrice, dtype: float64

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
albany_df = df[df['region']== 'Albany']
albany_df.head(10)
# Out:
#    Unnamed: 0       Date  AveragePrice  ...          type  year  region
# 0           0 2015-12-27          1.33  ...  conventional  2015  Albany
# 1           1 2015-12-20          1.35  ...  conventional  2015  Albany
# 2           2 2015-12-13          0.93  ...  conventional  2015  Albany
# 3           3 2015-12-06          1.08  ...  conventional  2015  Albany
# 4           4 2015-11-29          1.28  ...  conventional  2015  Albany
# 5           5 2015-11-22          1.26  ...  conventional  2015  Albany
# 6           6 2015-11-15          0.99  ...  conventional  2015  Albany
# 7           7 2015-11-08          0.98  ...  conventional  2015  Albany
# 8           8 2015-11-01          1.02  ...  conventional  2015  Albany
# 9           9 2015-10-25          1.07  ...  conventional  2015  Albany
#
# [10 rows x 14 columns]

# %%
albany_df.set_index('Date', inplace=True)

# %%
albany_df['AveragePrice'].plot() #visualize the data

# %%
albany_df['AveragePrice'].rolling(25).mean().plot()

# %%
albany_df.sort_index( inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
albany_df['AveragePrice'].rolling(25).mean().plot()

# %%
albany_df["price25ma"] = albany_df["AveragePrice"].rolling(25).mean()
albany_df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#             Unnamed: 0  AveragePrice  Total Volume  ...  year  region  price25ma
# Date                                                ...
# 2015-01-04          51          1.22      40873.28  ...  2015  Albany        NaN
# 2015-01-04          51          1.79       1373.95  ...  2015  Albany        NaN
# 2015-01-11          50          1.24      41195.08  ...  2015  Albany        NaN
# 2015-01-11          50          1.77       1182.56  ...  2015  Albany        NaN
# 2015-01-18          49          1.17      44511.28  ...  2015  Albany        NaN
#
# [5 rows x 14 columns]

# %%
albany_df.tail()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume  ...  year  region  price25ma
# Date                                                ...
# 2018-03-11           2          1.68       2570.52  ...  2018  Albany     1.4224
# 2018-03-18           1          1.66       3154.45  ...  2018  Albany     1.4316
# 2018-03-18           1          1.35     105304.65  ...  2018  Albany     1.4276
# 2018-03-25           0          1.57     149396.50  ...  2018  Albany     1.4272
# 2018-03-25           0          1.71       2321.82  ...  2018  Albany     1.4368
#
# [5 rows x 14 columns]

# %%
df['region']
# Out:
# 0                  Albany
# 1                  Albany
# 2                  Albany
# 3                  Albany
# 4                  Albany
#                ...
# 18244    WestTexNewMexico
# 18245    WestTexNewMexico
# 18246    WestTexNewMexico
# 18247    WestTexNewMexico
# 18248    WestTexNewMexico
# Name: region, Length: 18249, dtype: object

# %%
df['region'].values.tolist()
print(set(df['region'].values.tolist()))
# Out:
# {'Pittsburgh', 'StLouis', 'WestTexNewMexico', 'GreatLakes', 'Orlando', 'Houston', 'PhoenixTucson', 'BuffaloRochester', 'TotalUS', 'Chicago', 'Philadelphia', 'Northeast', 'GrandRapids', 'Nashville', 'Denver', 'MiamiFtLauderdale', 'BaltimoreWashington', 'Sacramento', 'Southeast', 'Detroit', 'Roanoke', 'West', 'Columbus', 'LosAngeles', 'RaleighGreensboro', 'Atlanta', 'Charlotte', 'Indianapolis', 'SanDiego', 'Portland', 'California', 'NorthernNewEngland', 'DallasFtWorth', 'SouthCarolina', 'LasVegas', 'HarrisburgScranton', 'Jacksonville', 'CincinnatiDayton', 'RichmondNorfolk', 'NewYork', 'Tampa', 'Louisville', 'Syracuse', 'SanFrancisco', 'Spokane', 'Albany', 'Plains', 'SouthCentral', 'Boston', 'Boise', 'HartfordSpringfield', 'NewOrleansMobile', 'Seattle', 'Midsouth'}

# %%
graph_df = pd.DataFrame()

for region in df['region'].unique()[:16]:
    print(region)
    region_df = df.copy()[df['region']==region]
    region_df.set_index('Date', inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f"{region}_price25ma"] = region_df["AveragePrice"].rolling(25).mean()

    if graph_df.empty:
        graph_df = region_df[[f"{region}_price25ma"]]  # note the double square brackets!
    else:
        graph_df = graph_df.join(region_df[f"{region}_price25ma"])
# Out:
# Albany
# Atlanta
# BaltimoreWashington
# Boise
# Boston
# BuffaloRochester
# California
# Charlotte
# Chicago
# CincinnatiDayton
# Columbus
# DallasFtWorth
# Denver
# Detroit
# GrandRapids
# GreatLakes

# %%
graph_df.tail(10)
# Out:
#             Albany_price25ma  ...  GreatLakes_price25ma
# Date                          ...
# 2018-03-25            1.4368  ...                1.2568
# 2018-03-25            1.4368  ...                1.2788
# 2018-03-25            1.4368  ...                1.2568
# 2018-03-25            1.4368  ...                1.2788
# 2018-03-25            1.4368  ...                1.2568
# 2018-03-25            1.4368  ...                1.2788
# 2018-03-25            1.4368  ...                1.2568
# 2018-03-25            1.4368  ...                1.2788
# 2018-03-25            1.4368  ...                1.2568
# 2018-03-25            1.4368  ...                1.2788
#
# [10 rows x 16 columns]

# %%
#select a organic type of avacado and do some calculations

df = df.copy()[df['type']=='organic']

df['Date'] = pd.to_datetime(df['Date'])

df.sort_values(by='Date', ascending=True, inplace=True)
df.head()
# Out:
#        Unnamed: 0       Date  AveragePrice  ...     type  year            region
# 9489           51 2015-01-04          1.24  ...  organic  2015        California
# 10269          51 2015-01-04          1.50  ...  organic  2015          LasVegas
# 10893          51 2015-01-04          1.12  ...  organic  2015     PhoenixTucson
# 9437           51 2015-01-04          1.73  ...  organic  2015  BuffaloRochester
# 11621          51 2015-01-04          1.30  ...  organic  2015           Spokane
#
# [5 rows x 14 columns]

# %%
graph_df = pd.DataFrame()

for region in df['region'].unique():
    region_df = df.copy()[df['region']==region]
    region_df.set_index('Date', inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f"{region}_price25ma"] = region_df["AveragePrice"].rolling(25).mean()

    if graph_df.empty:
        graph_df = region_df[[f"{region}_price25ma"]]  # note the double square brackets! (so df rather than series)
    else:
        graph_df = graph_df.join(region_df[f"{region}_price25ma"])

graph_df.tail()
# Out:
#             California_price25ma  ...  NewYork_price25ma
# Date                              ...
# 2018-02-25                1.9128  ...             1.9308
# 2018-03-04                1.8876  ...             1.9156
# 2018-03-11                1.8636  ...             1.9092
# 2018-03-18                1.8516  ...             1.8948
# 2018-03-25                1.8364  ...             1.8876
#
# [5 rows x 54 columns]

# %%
graph_df.plot(figsize=(10,7), legend=False)
